# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
data = yf.download("AAPL", start="2023-01-01", end="2024-01-01")
print(data.head())

# %%
apple = yf.Ticker("AAPL")
print(apple.balance_sheet)

# %%
apple.history(period="1y")["Close"].plot()
# Out:
# <Axes: xlabel='Date'>
